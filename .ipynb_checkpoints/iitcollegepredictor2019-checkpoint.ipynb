# %%
import pandas as pd
import numpy as np

data=pd.read_excel('openingclosingranks2019.xlsx')
mask1=data['ClosingRank'].str.contains('P',na=False,regex=True)==False
data=data[mask1]


mask2=(data['Category']=='OBC-NCL') & (data['SeatPool']=='Gender-Neutral')
mask3=(data['ClosingRank']>2290) & (mask2)
result = data[mask3].sort_values(by=['OpeningRank'])
result.head(20)
# Out:
#                                           Institute  \
# 807        Indian Institute of Technology Kharagpur
# 2073        Indian Institute of Technology Guwahati
# 1844  Indian Institute of Technology (BHU) Varanasi
# 952        Indian Institute of Technology Hyderabad
# 2129        Indian Institute of Technology Guwahati
# 2298        Indian Institute of Technology Tirupati
# 921        Indian Institute of Technology Hyderabad
# 354            Indian Institute of Technology Delhi
# 1016         Indian Institute of Technology Jodhpur
# 2248        Indian Institute of Technology Palakkad
# 1115          Indian Institute of Technology Kanpur
# 1275          Indian Institute of Technology Madras
# 1289          Indian Institute of Technology Madras
# 1410           Indian Institute of Technology Patna
# 1680   Indian Institute of Technology (ISM) Dhanbad
# 876        Indian Institute of Technology Kharagpur
# 746        Indian Institute of Technology Kharagpur
# ...
